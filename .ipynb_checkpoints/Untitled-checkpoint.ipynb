# %% [markdown]
# # PGA Tour Player Performance: Web Scrape

# %%
#import modules
import pandas as pd
from splinter import Browser
from bs4 import BeautifulSoup
import requests
import time

# %%
#URL of page to be scraped
url = 'https://www.pgatour.com/players.html'

# %%
#Retrieve page with the requests module
response = requests.get(url)

# %%
#create BeautifulSoup object; parse w 'html.parser'
soup = BeautifulSoup(response.text, 'html.parser')

# %% [markdown]
# ### Step 1: Scrape Link to Each Player Stat Page

# %%
# #execute chromedriver
# executable_path = {'executable_path': 'chromedriver.exe'}
# browser = Browser('chrome', **executable_path, headless=False)
# browser.visit(url)

# %%
#get html code via beautifulsoup
# html = browser.html
# soup = BeautifulSoup(html, 'html.parser')
#soup.prettify()

# %%
#get names of all the player links
#retrieve the parent divs for all links
players = soup.find_all('span',class_="name")

# %%
#create empty list to accept data
player_names = []
player_url = []

#loop through each parent div and grab the link to the player stat page
for player in players:
    #get name of player
    player_names.append(player.a.text)
    #get url for player performance page
    player_url.append(player.a['href'])

# %% [markdown]
# ### Step 2: Scrape PGA Performance Data for Each Individual Player

# %%
#create url for player
base_url = 'https://www.pgatour.com'
test_url = player_url[107]
scrape_url = base_url + test_url
#scrape_url = "https://www.pgatour.com/players/player.01006.john-adams.html"

#go to url page
response = requests.get(scrape_url)
soup = BeautifulSoup(response.text, 'html.parser')

scrape_url
# Out:
# 'https://www.pgatour.com/players/player.52372.cameron-champ.html'

# %%
# test = soup.find('div', class_='wrap').find('div', class_='tabbable').find('div', class_="performance").find('div',class_='tab-content') \
# .find('div', class_='tab-pane')#.find('div', class_='tour-year-filter-container')
# test

# %% [markdown]
# ### Splinter Method

# %%
#execute chromedriver
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
browser.visit(scrape_url)

# %%
browser.click_link_by_partial_text("Performance")
time.sleep(1)

# %%
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
test = soup.find('div', class_='wrap').find('div', class_='tabbable').find('div', class_="performance").find('div',class_='tab-content') \
.find('div', class_='tab-pane')#.find('div', class_='tour-year-filter-container')
test
# Out:
# <div class="tab-pane active" id="performanceSeason">
# <div class="player-performance-season-module" id="module-1557043856048-140193-17">
# <div class="tour-year-filter-block">
# <div class="tour-year-filter-container" id="module-1557043857987-142450-48"><div class="performance-head clearfix" data-reactroot=""><div class="subtitle">2019 PGA TOUR Season Stats</div><div class="addition"><div class="select year"><div><select class="hasCustomSelect" style="-webkit-appearance: menulist-button; position: absolute; opacity: 0; height: 35px; font-size: 16px; width: 98px;"><option value="2019">2019</option>,<option value="2018">2018</option>,<option value="2017">2017</option></select><span class="customSelect" style="display: inline-block;"><span class="customSelectInner" style="width: 982px; display: inline-block;">2019</span></span></div></div><div class="select tour"><div><select class="hasCustomSelect" style="-webkit-appearance: menulist-button; position: absolute; opacity: 0; height: 35px; font-size: 16px; width: 228px;"><option value="r">PGA TOUR</option>,<option value="h">Web.com Tour</option></select><span class="customSelect" style="display: inline-block;"><span class="customSelectInner" style="width: 982px; display: inline-block;">PGA TOUR</span></span></div></div></div></div></div>
# <div class="render"><div data-reactroot=""><div><div class="category open"><div class="category-name">Recap</div><div class="category-content clearfix"><ul class="slider"><li class="full slide"><div class="recap clearfix"><div class="item"><div class="main"><div class="rank">11th</div><div class="title">.629</div><div class="name">SG: Off-the-Tee</div></div><div class="addition"><div class="stat"><div class="value">22.626</div><div class="caption">Total SG:OTT</div></div><div class="stat"><div class="value">36</div><div class="caption">Measured Rounds</div></div></div></div><div class="item"><div class="main"><div class="rank">139th</div><div class="title">-.140</div><div class="name">SG: Approach-the-Green</div></div><div class="addition"><div class="stat"><div class="value">-5.056</div><div class="caption">Total SG:APP</div></div><div class="stat"><div class="value">36</div><div class="caption">Measured Rounds</div></div></div></div><div class="item"><div class="main"><div class="rank">212th</div><div class="title">-.630</div><div class="name">SG: Around-the-Green</div></div><div class="addition"><div class="stat"><div class="value">-22.663</div><div class="caption">Total SG:ARG</div></div><div class="stat"><div class="value">36</div><div class="caption">Measured Rounds</div></div></div></div><div class="item"><div class="main"><div class="rank">31st</div><div class="title">.451</div><div class="name">SG: Putting</div></div><div class="addition"><div class="stat"><div class="value">16.226</div><div class="caption">Total SG:Putting</div></div><div class="stat"><div class="value">36</div><div class="caption">Measured Rounds</div></div></div></div><div class="item"><div class="main"><div class="rank">127th</div><div class="title">-.142</div><div class="name">SG: Tee-to-Green</div></div><div class="addition"><div class="stat"><div class="value">.629</div><div class="caption">SG:OTT</div></div><div class="stat"><div class="value">36</div><div class="caption">Measured Rounds</div></div></div></div><div class="item"><div class="main"><div class="rank">82nd</div><div class="title">.309</div><div class="name">SG: Total</div></div><div class="addition"><div class="stat"><div class="value">11.131</div><div class="caption">Total SG:T</div></div><div class="stat"><div class="value">36</div><div class="caption">Measured Rounds</div></div></div></div></div></li><li class="half slide"><table class="table remaining"><thead><tr><th colspan="2">Standard stats</th><th class="rank">Rank</th></tr></thead><tbody><tr><td class="caption">Driving Distance</td><td class="value">314.8</td><td class="rank">1st</td></tr><tr><td class="caption">Driving Accuracy Percentage</td><td class="value">54.93%</td><td class="rank">193rd</td></tr><tr><td class="caption">Greens in Regulation Percentage</td><td class="value">71.97%</td><td class="rank">9th</td></tr><tr><td class="caption">Eagles (Holes per)</td><td class="value">113.1</td><td class="rank">31st</td></tr><tr><td class="caption">Birdie Average</td><td class="value">4.66</td><td class="rank">6th</td></tr><tr><td class="caption">Scoring Average</td><td class="value">70.893</td><td class="rank">65th</td></tr><tr><td class="caption">Sand Save Percentage</td><td class="value">35.59%</td><td class="rank">212th</td></tr><tr><td class="caption">FedExCup Season Points</td><td class="value">619</td><td class="rank">36th</td></tr><tr><td class="caption">Official Money</td><td class="value">$1,515,091</td><td class="rank">41st</td></tr><tr><td class="caption">Official World Golf Ranking</td><td class="value">1.42</td><td class="rank">96th</td></tr></tbody></table></li><li class="half"><table class="table addition"><thead><tr><th colspan="2">Supporting Stats</th></tr></thead><tbody><tr><td>Total Distance: 27,701</td><td>Total Drives: 88</td></tr><tr><td>Fairways Hit: 340</td><td>Possible Fairways: 619</td></tr><tr><td>Greens Hit: 570</td><td># Holes: 792</td></tr><tr><td># of Holes: 792</td><td># of Eagles: 7</td></t ...
# </div>
# </div>
# <script>
#     var config = {
#         pid: '52372',
#         disableModule: false,
#         primaryTour: 'r',
#         minYear: 1980,
#         statJsonUrl: 'https://statdata.pgatour.com/players/{pid}/{year}stat.json',
#         careerJsonUrl: 'https://statdata.pgatour.com/players/{pid}/career.json',
#         localization: {
#             title: '{year} {tour} Season Stats',
#             preloader: 'Please wait ... loading',
#             noData: 'Statistics for the selected Tour and Year are not available',
#             legend: {
#                 title: 'LEGEND',
#                 aboveAverage: 'Above Average',
#                 aboveAverageShort: 'Above Avg.',
#                 average: 'Average',
#                 averageShort: 'Avg.',
#                 belowAverage: 'Below Average',
#                 belowAverageShort: 'Below Avg.'
#             },
#             standardStatsTable: {
#                 title: 'Standard stats',
#                 rank: 'Rank'
#             },
#             additionalStatsTable: {
#                 title: 'Supporting Stats'
#             },
#             ending: [
#                 'th',
#                 'st',
#                 'nd',
#                 'rd'
#             ]
#         }
#     };
#
#     new pgatour.PlayerPerformanceSeason(jQuery('.player-performance-season-module'), config);
# </script></div>

# %%
test = soup.findAll('table', class_='table remaining')

# %%
numbers=[]

for i in test:
    joey=i.text
    print(joey)
# Out:
# Standard statsRankDriving Distance314.81stDriving Accuracy Percentage54.93%193rdGreens in Regulation Percentage71.97%9thEagles (Holes per)113.131stBirdie Average4.666thScoring Average70.89365thSand Save Percentage35.59%212thFedExCup Season Points61936thOfficial Money$1,515,09141stOfficial World Golf Ranking1.4296th
# Standard statsRankDistance from Edge of Fairway30' 9"165thLeft Rough Tendency15.83%183rdRight Rough Tendency19.24%182ndTotal Driving19478thClub Head Speed129.721stTotal Driving Efficiency341180th
# Standard statsRankRough Proximity43' 0"69thLeft Rough Proximity43' 8"96thRight Rough Proximity42' 5"72ndFairway Proximity33' 10"164thApproaches from > 275 yards120' 5"200thApproaches from 250-275 yards74' 3"166thApproaches from 225-250 yards50' 9"76thApproaches from 200-225 yards44' 2"147thApproaches from 50-75 yards17' 4"133rdApproaches from 75-100 yards18' 8"137thApproaches from 100-125 yards28' 5"212thApproaches from 50-125 yards23' 7"207thApproaches from 125-150 yards26' 2"175thApproaches from 150-175 yards29' 11"158thApproaches from 175-200 yards34' 5"111thApproaches from > 200 yards53' 3"128thApproaches from > 275 yards (Rgh)37' 5"8thApproaches from 250-275 yards (Rgh)100' 5"158thApproaches from 225-250 yards (Rgh)72' 0"88thApproaches from 200-225 yards (Rgh)57' 10"54thApproaches from > 100 yards (Rgh)46' 8"93rdApproaches from inside 100 yards (Rgh)28' 6"159thApproaches from > 200 yards (Rgh)62' 8"24thApproaches from 175-200 yards (Rgh)65' 5"197thApproaches from 150-175 yards (Rgh)36' 2"54thApproaches from 125-150 yards (Rgh)41' 0"185thApproaches from 50-125 yards (Rgh)29' 2"143rdApproaches from 100-125 yards (Rgh)30' 6"132ndApproaches from 75-100 yards (Rgh)26' 5"128thApproaches from 50-75 yards (Rgh)30' 11"165thTotal Hole Outs6101stLongest Hole Outs (in yards)7882nd
# Standard statsRankScrambling from > 30 yards20.69%169thScrambling from 20-30 yards43.18%180thScrambling from 10-20 yards55.13%203rdScrambling from < 10 yards88.57%69th
# Standard statsRankPutts Per Round29.68196thPutts per Round - Round 130.64208thPutts per Round - Round 229.00110thPutts per Round - Round 329.22147thPutts per Round - Round 429.63167thPutting from 3'98.96%171stPutting from 4'89.04%148thPutting from 5'80.36%111thPutting from 6'73.33%77thPutting from 7'63.16%73rdPutting from 8'52.63%101stPutting from 9'57.14%37thPutting from 10'44.00%74thPutting from 4-8'70.63%63rdPutting - Inside 10'87.77%83rdPutting from - 10-15'35.79%43rdPutting from - 15-20'18.06%96thPutting from - 20-25'10.71%123rdPutting from - > 25'9.04%18thLongest Putts59' 6"24thApproach Putt Performance2' 5"175thAverage Distance of Putts made82' 9"6thBirdie or Better Conversion Percentage36.73%9th
# Standard statsRankTotal Eagles724thEagles (Holes per)113.131stPar Breakers26.77%5thRound 1 Scoring Average71.71171stRound 2 Scoring Average68.625thRound 3 Scoring Average69.4446thRound 4 Scoring Average69.7553rdFinal Round Scoring Average69.7553rdFront 9 Scoring Average35.1685thBack 9 Scoring Average34.8224thEarly Scoring Average70.74133rdLate Scoring Average69.4012thPar 3 Scoring Average2.9919thPar 4 Scoring Average4.0167thPar 5 Scoring Average4.5324thFinal Round Performance50.00%104thPar 3 Birdie or Better Leaders21.39%2ndPar 4 Birdie or Better Leaders19.53%31stPar 5 Birdie or Better Leaders56.08%10thBirdie or Better Percentage26.77%5thBounce Back23.53%60th
# Standard statsRankConsecutive GIR2027thConsecutive Holes Below Par513thConsecutive Par 3 Birdies51stConsecutive Birdies Streak511thConsecutive Birdies/Eagles streak48th

# %%
test = soup.findAll('div', class_='item')

# %%
numbers=[]

for i in test:
    joey=i.text
    print(joey)
# Out:
# 6  ft, 0  in
# 183 cm
# Height
#
#
# 175 lbs
# 79 kg
# Weight
#
#
# 23
# AGE
#
#
# 2017
# Turned Pro
#
#
# Texas A&M University
# College
#
#
# Sacramento, California
# Birthplace
#
#
# 6  ft, 0  in
# 183 cm
# Height
#
#
# 175 lbs
# 79 kg
# Weight
#
#
# 23
# AGE
#
#
# 2017
# Turned Pro
#
#
# Texas A&M University
# College
#
#
# Sacramento, California
# Birthplace
#
#
#
# 36
# FEDEXCUP Rank
#
#
# 619
# FEDEXCUP Points
#
#
#
# 96
# OWGR
#
#
# 70.893
# Scoring Average
#
# Hole 9
# Par 4
# 505yds
# 11th.629SG: Off-the-Tee22.626Total SG:OTT36Measured Rounds
# 139th-.140SG: Approach-the-Green-5.056Total SG:APP36Measured Rounds
# 212th-.630SG: Around-the-Green-22.663Total SG:ARG36Measured Rounds
# 31st.451SG: Putting16.226Total SG:Putting36Measured Rounds
# 127th-.142SG: Tee-to-Green.629SG:OTT36Measured Rounds
# 82nd.309SG: Total11.131Total SG:T36Measured Rounds
# 127th-.142SG: Tee-to-Green.629SG:OTT36Measured Rounds
# 11th.629SG: Off-the-Tee22.626Total SG:OTT36Measured Rounds
# 1st314.8Driving Distance27,701Total Distance88Total Drives
# 3rd303.8Driving Distance - All Drives154,309Total Distance508# of Drives
# 17th409Longest DrivesSentryTournament2Round
# 193rd54.93%Driving Accuracy Percentage340Fairways Hit619Possible Fairways
# 139th-.140SG: Approach-the-Green-5.056Total SG:APP36Measured Rounds
# 9th71.97%Greens in Regulation Percentage570Greens Hit792# Holes
# 13th75.86%Going for the Green110Attempts35Non-Attempts
# 11th30.51%Going for the Green - Hit Green Pct.36Successes118Attempts
# 48th61.86%Going for the Green - Birdie or Better73# of Birdie or Better118Attempts
# 170th39' 0"Proximity to Hole25,100.500Total Distance (feet)644# of Attempts
# 212th-.630SG: Around-the-Green-22.663Total SG:ARG36Measured Rounds
# 212th35.59%Sand Save Percentage21# Saves59# Bunkers
# 209th13' 0"Proximity to Hole from Sand533.083Total Distance (feet)41# of Shots
# 211th51.35%Scrambling114Par or Better222Missed GIR
# 68th94.44%Scrambling from the Fringe17Successes18Attempts
# 209th44.00%Scrambling from the Rough33Successes75Attempts
# 31st.451SG: Putting16.226Total SG:Putting36Measured Rounds
# 88th209.1Total Putting
# 56th1.742Putting Average993GIR Putts570Greens Hit
# 196th1.649Overall Putting Average1,306# of Putts792# of Holes
# 160th38.26%One-Putt Percentage303# of 1 putts792# of holes
# 207th4.55%3-Putt Avoidance36Total 3 Putts792Total Holes (overall)
# 82nd.309SG: Total11.131Total SG:T36Measured Rounds
# 7th62Lowest RoundMayakoba/El CamTourn/Course2Round
# 65th70.893Scoring Average3,079Total Strokes40.311Total Adjustment
# 38th69.98Scoring Average (Actual)3,079Total Strokes44Total Rounds
# 6th4.66Birdie Average205# of Birdies44Total Rounds
# 16th205Total Birdies
# 35th13YTD Par or Better Streak
# 80th7Best YTD 1-Putt or Better Streak
# 105th120Best YTD Streak w/o a 3-Putt4Current Streak
# 184th4Current Streak without a 3-Putt
# 91st5Consecutive Sand Saves0Current Streak3Round
# 73rd15Consecutive Fairways Hit3Current Streak

# %%
import bs4 as bs
import urllib.request

source = urllib.request.urlopen('https://www.pgatour.com/players/player.01006.john-adams.html')
soup = bs.BeautifulSoup(source,'html.parser')

#js_test = soup.find('p', class_='jstest')

soup.find('div', class_='wrap').find('div', class_='tabbable').find('div', class_="performance").find('div',class_='tab-content') \
.find('div', class_='tab-pane')#.find('div', class_='tour-year-filter-container')
test
