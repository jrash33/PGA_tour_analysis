# %%
#import modules
import pandas as pd
from splinter import Browser
from bs4 import BeautifulSoup
import requests
import time

#FUNCTIONS
#function that takes desired variables with your list of dictionaries scraped and returns a clean list of these variables
def get_vars(stats, vars_wanted):
    stats_vars = []
    items=[]
    #iterate through scraped data to find desired variables
    for list_item in stats:
        dict_item = [key for key,value in list_item.items()]
        if dict_item[0] in vars_wanted:
            #check for duplicates
            if dict_item not in items:
                items.append(dict_item)
                stats_vars.append(list_item)
    return stats_vars


#---------------------------------------------------------------------------------------------------------------------------
#MAIN

#URL of page to be scraped
url = 'https://www.pgatour.com/players.html'

#Retrieve page with the requests module
response = requests.get(url)

#create BeautifulSoup object; parse w 'html.parser'
soup = BeautifulSoup(response.text, 'html.parser')


#SCRAPE LINK TO EACH PLAYER STAT PAGE***********************************
#get names of all the player links
#retrieve the parent divs for all links
#players = soup.find_all('span',class_="name")

#create empty list to accept data
player_names = []
player_url = []

#loop through each parent div and grab the link to the player stat page
for player in players[player_count:]:
    #get name of player
    player_names.append(player.a.text)
    #get url for player performance page
    player_url.append(player.a['href'])


#SCRAPE PGA PERFORMANCE DATA FOR EACH INDIVIDUAL PLAYER******************
base_url = 'https://www.pgatour.com'

#execute chromedriver
# executable_path = {'executable_path': 'chromedriver.exe'}
# browser = Browser('chrome', **executable_path, headless=False)

#master data set
#DATA = []
#keep track of player count
#player_count = 0
#keep track of the players unable to scrape
#error_player = []

for player,url in zip(player_names,player_url):
    executable_path = {'executable_path': 'chromedriver.exe'}
    browser = Browser('chrome', **executable_path, headless=True)
    time.sleep(2)
    
    scrape_url = base_url + url
    print("scraped URL")

    #SPLINTER
    print("try visit url")
    browser.visit(scrape_url)
    time.sleep(8)
    print("done visit url")
    
    #if pop-up add comes up, wait it out
    try:
        print("try click performance")
        browser.click_link_by_partial_text("Performance")
        time.sleep(2)
        print("done click performance")
    except:
        print("except try click performance")
        time.sleep(10)
        browser.click_link_by_partial_text("Performance")
        time.sleep(2)
        print("done click performance except")

    try:
        html = browser.html
        soup = BeautifulSoup(html, 'html.parser')   
        
        #INTRO/PLAYER INFO DATA########################################################################
        #photo of player
        try:
            photo_url = soup.find('img', class_='photo')['src']
            player_intro = {'Player Name': player.replace('\xa0',' '), 'photo_url': photo_url}
        except TypeError:
            player_intro = {'Player Name': player.replace('\xa0',' '), 'photo_url': 'none'}

        #scrape all html hstat code
        info = soup.findAll('div', class_='item')

        #headline stats
        info_stats = []

        for i in info:
            try:
                #get stat name
                caption = i.find('div',class_='denotation').text
                #get stat value
                value = i.find('div', class_='value').text
                #clean up text
                value = value.replace('\xa0','')
                value = value.replace('\n','')
                #save to dictionary
                post = {'caption':caption, 'value': value}
                #append to list
                info_stats.append(post)
            except AttributeError:
                nothing = 0
                
        ####TOURNAMENT DATA###########################################################################
        bla = soup.findAll('div', class_ = 'holder')
        dates_ = soup.findAll('td', class_ = 'date')
        rounds = soup.findAll('td', class_='round')

        tourney_name = []
        all_text = []
        scores = []
        to_par = []
        pos = []
        dates = []

        for i in bla:
            x = i.find('tbody')
            #tourney info
            tourneys = x.findAll('p')
            #need this for all text
            tds = x.findAll('td')
            #get all text to use later for pos
            [all_text.append(td.text) for td in tds]
            
            #tournament names
            [tourney_name.append(j.text) for j in tourneys]

        #clean dates
        [dates.append(d.text) for d in dates_]
        #scores of each round in increments of 4 ('--' means no score)
        [scores.append(r.text) for r in rounds]
        #now append tournament position results by getting list item after tournament name
        [pos.append(all_text[all_text.index(tourney)+1]) for tourney in tourney_name]
        #now append tournament position results by getting list item after tournament name
        [to_par.append(all_text[all_text.index(tourney)+8]) for tourney in tourney_name]

        #create final dictionary of tournaments for the past year
        tournament_history = []
        for date,tourney,score,rank in zip(dates,tourney_name,to_par,pos):
            try:
                #create dictionary with all info
                post = {'Date':date, 
                        'Tournament Name':tourney, 
                        'Total Score':score, 
                        'POS':rank}
                #append to final list
                tournament_history.append(post)
            except AttributeError:
                nothing=0
        
        #PERFORMANCE DATA##############################################################################
        
        dropdown = browser.find_by_xpath("//div[@class='select year']//select[@class='hasCustomSelect']")
        h_stats_all = []
        a_stats_all = []
        extra_stats_var_all = []
        for option in dropdown.find_by_tag('option'):  
            option.click()
            time.sleep(2)
            try:
                html = browser.html
                soup = BeautifulSoup(html, 'html.parser')
            except:
                time.sleep(10)
                html = browser.html
                soup = BeautifulSoup(html, 'html.parser')

            #scrape all html hstat code
            hstats = soup.findAll('div', class_='stat')

            #headline stats
            h_stats = []
            year = {"year":option.text}
            h_stats.append(year)

            for hstat in hstats:
                try:
                    #get stat name
                    caption = hstat.find('div',class_='caption').text
                    #get stat value
                    value = hstat.find('div',class_='value').text

                    #save to dictionary
                    #post = {'caption':caption, 'value': value}
                    post = {caption : value}

                    #append to list
                    h_stats.append(post)
                except AttributeError:
                    nothing = 0

            h_stats_all.append(h_stats)

            #scrape all html astat code
            astats = soup.findAll('tr')

            #attribute stats
            a_stats = []
            year = {"year":option.text}
            a_stats.append(year)

            for astat in astats:
                try:
                    #get the stat name
                    caption = astat.find('td',class_='caption').text
                    #get stat value
                    value = astat.find('td',class_='value').text

                    #save to dictionary
                    post = {caption : value}

                    #append to list
                    a_stats.append(post)
                except AttributeError:
                    nothing = 0

            a_stats_all.append(a_stats)

            #scrape for additional needed info
            extrastats = soup.findAll('td')

            #attribute stats
            extra_stats = []

            for extra in extrastats:
                try:
                    #get the stat name
                    text = extra.text
                    #append to list
                    extra_stats.append(text)
                except AttributeError:
                    nothing=0

            #these attributes are unique with no captions/values-All string format
            #search sub_strings of desired variables for values
            sub_strings = ['Total Left rough', 'Total Right rough', 'Possible Fwys', 'Distance Rank', 'Accuracy Rank',
                  'Total Club Head Speed', 'Total Attempts']
            extra_stats_var= []
            year = {"year":option.text}
            extra_stats_var.append(year)
            for sub in sub_strings:
                x = [s for s in extra_stats if sub in s]
                if x:
                    x = x[0].split(':')
                    x[1] = x[1].replace(' ','')

                    #post = {'caption': x[0], 'value': x[1]}
                    post = {x[0] : x[1]}
                    extra_stats_var.append(post)
                else:
                    nothing=0

            extra_stats_var_all.append(extra_stats_var)

        #variables wanted from info stats
        info_var = ['year','Height', 'Weight', 'AGE', 'Turned Pro', 'College', 'Birthplace' ,'FEDEXCUP Rank', 'FEDEXCUP Points', 'Scoring Average']
        #variables wanted from headline stats
        h_var = ['year','Total Distance', 'Total Drives', '# of Drives', 'Fairways Hit', 'Possible Fairways', 'Measured Rounds']
        #variables wanted from additional stats
        a_var = ['year','Driving Distance','Driving Accuracy Percentage','Total Driving','Club Head Speed',
                'Distance from Edge of Fairway','Left Rough Tendency','Right Rough Tendency','Total Driving Efficiency']
        extra_var = ['year','Total Left rough', 'Total Right rough', 'Possible Fwys', 'Distance Rank', 'Accuracy Rank',
            'Total Club Head Speed', 'Total Attempts']
        
        #get only desired variables listed above
        info_stats_vars = get_vars(info_stats, info_var)
        h_stats_vars = [get_vars(h_stats, h_var) for h_stats in h_stats_all]
        a_stats_vars = [get_vars(a_stats, a_var) for a_stats in a_stats_all]
        extra_stats_vars = [get_vars(extra_stats, extra_var) for extra_stats in extra_stats_var_all]
        
        #convert lists with dictionaries to 1 list with big dictionary
        info_stats_vars = {key: value for info_stat in info_stats_vars for key, value in info_stat.items()}
        #all years of stats
        a_stats_vars = [{key: value for a_stat in list_item for key, value in a_stat.items()} for list_item in a_stats_vars]
        h_stats_vars = [{key: value for a_stat in list_item for key, value in a_stat.items()} for list_item in h_stats_vars]
        extra_stats_vars = [{key: value for a_stat in list_item for key, value in a_stat.items()} for list_item in extra_stats_vars]
        
        #combine all statistic variables into one list of dictionaries
        all_stat_var =[]
        for a_stat, h_stat, extra_stat in zip(a_stats_vars, h_stats_vars, extra_stats_vars):
            temp_dict = {}
            temp_dict.update(a_stat)
            temp_dict.update(h_stat)
            temp_dict.update(extra_stat)

            all_stat_var.append(temp_dict)
    
        #output list
        player_final = {}
        player_final['player_intro'] = player_intro
        player_final['info'] = info_stats_vars
        player_final['all_stat_var'] = all_stat_var
        player_final['tournament_hist'] = tournament_history

        DATA.append(player_final)
        print(f"{player_count} Player Data Successfully Acquired!: {player}")
        player_count += 1
        browser.quit()
    
    except:
        error_player.append(player_count)
        print(f"{player_count} !!!!!!!!!!!Data Retrieval Unsuccessful: {player}")
        player_count += 1
        browser.quit()
        
    
    
#PART 2: TITLEIST WEB SCRAPE
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)
url = "https://www.titleist.com/tour/pga/players"
base_url = "https://www.titleist.com"
browser.visit(url)
time.sleep(2)

#close pop-up
try:
    browser.find_by_css("Button")[11].click()
except:
    print("No Pop Up")
    
#info we will scrape
done = 0
titleist_players = []

while done != 1:
    try:
        
        html = browser.html
        soup = BeautifulSoup(html, 'html.parser')
        
        #scrape all html hstat code
        test = soup.findAll('li', class_='m-results-item')
        
        for t in test:

            #name of player
            n = t.find('h2', class_='m-results-label').text
            #format name to match other data scraped
            n = n.replace(' ', '')
            n = n.replace('\n', '')
            isupper = [letter.isupper() for letter in n]
            n = n + ", "
            #index of last name starting
            last_name_index = [i for i, x in enumerate(isupper) if x][1]
            #break up
            first_name = n[0:last_name_index]
            last_name = n[last_name_index:]
            n = last_name + first_name
            name = n

            #equipment using
            e = t.find('em').text
            #name.append(n)
            equipment = e

            if e == 'Brand Ambassador':
                player_page = t.find('h2', class_='m-results-label').a['href']
                club_url = base_url + player_page
                browser.visit(club_url)
                html = browser.html
                soup = BeautifulSoup(html, 'html.parser')
                try:
                    driver = soup.find('div', class_ = "m-category-listing-content").a.text
                    driver = driver.replace(" ", "")
                    driver = driver.replace("\n", "")
                    type_equipment = driver
                    browser.back()
                except:
                    golf_ball = t.findAll('p')
                    ball = [b.text for b in golf_ball]
                    ball = ball[1]
                    ball = ball.replace("Brand Ambassador", "")
                    type_equipment = ball
                    browser.back()
            else:
                golf_ball = t.findAll('p')
                ball = [b.text for b in golf_ball]
                ball = ball[1]
                ball = ball.replace("Golf Ball Player", "")
                type_equipment = ball
            
            #put needed info to dictionary
            post = {'Player Name': n, 
            'Type': equipment, 
            'Equipment': type_equipment, 
            }
            
            #append each player to list
            titleist_players.append(post)
                    
        browser.click_link_by_partial_text("Next")
        time.sleep(1)
    except:
        done=1
        
browser.quit()
# Out:
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 0 Player Data Successfully Acquired!: Adams, John
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 1 Player Data Successfully Acquired!: Adams, Sam
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 2 Player Data Successfully Acquired!: Aguilar, Felipe
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 3 Player Data Successfully Acquired!: Albertson, Anders
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 4 Player Data Successfully Acquired!: Aldridge, Tyler
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 5 Player Data Successfully Acquired!: Alker, Steven
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 6 Player Data Successfully Acquired!: Allem, Fulton
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 7 Player Data Successfully Acquired!: Allen, Michael
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 8 Player Data Successfully Acquired!: Allenby, Robert
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 9 Player Data Successfully Acquired!: Ames, Stephen
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 10 Player Data Successfully Acquired!: An, Byeong Hun
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 11 Player Data Successfully Acquired!: Ancer, Abraham
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 12 Player Data Successfully Acquired!: Andersson Hed, Fredrik
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 13 Player Data Successfully Acquired!: Andrade, Billy
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 14 Player Data Successfully Acquired!: Aoki, Isao
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 15 Player Data Successfully Acquired!: Aphibarnrat, Kiradech
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 16 Player Data Successfully Acquired!: Appleby, Stuart
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 17 Player Data Successfully Acquired!: Armour, Ryan
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 18 Player Data Successfully Acquired!: Armour III, Tommy
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 19 Player Data Successfully Acquired!: Armstrong, Wally
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 20 Player Data Successfully Acquired!: Atwal, Arjun
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 21 Player Data Successfully Acquired!: Austin, Woody
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 22 Player Data Successfully Acquired!: Axley, Eric
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 23 Player Data Successfully Acquired!: Azinger, Paul
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 24 Player Data Successfully Acquired!: Baddeley, Aaron
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 25 Player Data Successfully Acquired!: Bae, Sangmoon
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 26 Player Data Successfully Acquired!: Baird, Briny
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 27 Player Data Successfully Acquired!: Baker-Finch, Ian
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 28 Player Data Successfully Acquired!: Barlow, Craig
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 29 Player Data Successfully Acquired!: Barnes, Ricky
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 30 Player Data Successfully Acquired!: Barr, Dave
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 31 Player Data Successfully Acquired!: Bateman, Brian
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 32 Player Data Successfully Acquired!: Bean, Andy
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 33 Player Data Successfully Acquired!: Beck, Chip
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 34 Player Data Successfully Acquired!: Beckman, Cameron
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 35 Player Data Successfully Acquired!: Beem, Rich
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 36 Player Data Successfully Acquired!: Begay III, Notah
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 37 Player Data Successfully Acquired!: Beljan, Charlie
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 38 Player Data Successfully Acquired!: Beman, Deane
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 39 Player Data Successfully Acquired!: Benepe, Jim
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 40 Player Data Successfully Acquired!: Berganio, Jr., David
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 41 Player Data Successfully Acquired!: Berger, Daniel
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 42 Player Data Successfully Acquired!: Besselink, Al
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 43 Player Data Successfully Acquired!: Bettencourt, Matt
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 44 Player Data Successfully Acquired!: Bhullar, Gaganjeet
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 45 Player Data Successfully Acquired!: Bilodeau, Kyle
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 46 Player Data Successfully Acquired!: Bjerregaard, Lucas
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 47 Player Data Successfully Acquired!: BjÃ¶rk, Alexander
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 48 Player Data Successfully Acquired!: BjÃ¸rn, Thomas
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 49 Player Data Successfully Acquired!: Black, Ronnie
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 50 Player Data Successfully Acquired!: Blackburn, Woody
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 51 Player Data Successfully Acquired!: Blackmar, Phil
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 52 Player Data Successfully Acquired!: Blair, Zac
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 53 Player Data Successfully Acquired!: Blake, Jay Don
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 54 Player Data Successfully Acquired!: Blancas, Homero
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 55 Player Data Successfully Acquired!: Blanks, Kris
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 56 Player Data Successfully Acquired!: Blaum, Ryan
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 57 Player Data Successfully Acquired!: Blixt, Jonas
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 58 Player Data Successfully Acquired!: Bohn, Jason
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 59 Player Data Successfully Acquired!: Boros, Guy
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 60 Player Data Successfully Acquired!: Boros, Julius
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 61 Player Data Successfully Acquired!: Both, Marcus
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 62 Player Data Successfully Acquired!: Bourdy, GrÃ©gory
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 63 Player Data Successfully Acquired!: Bowditch, Steven
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 64 Player Data Successfully Acquired!: Bozzelli, Dominic
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 65 Player Data Successfully Acquired!: Bradley, Keegan
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 66 Player Data Successfully Acquired!: Bradley, Michael
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 67 Player Data Successfully Acquired!: Brooks, Mark
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 68 Player Data Successfully Acquired!: Brown, Billy Ray
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 69 !!!!!!!!!!!Data Retrieval Unsuccessful: Brown, Bud
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 70 Player Data Successfully Acquired!: Brown, Ken
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 71 Player Data Successfully Acquired!: Brown, Mark
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 72 Player Data Successfully Acquired!: Brown, Mark
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 73 Player Data Successfully Acquired!: Brown, Scott
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 74 Player Data Successfully Acquired!: Browne, Olin
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 75 Player Data Successfully Acquired!: Bryan, Wesley
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 76 Player Data Successfully Acquired!: Bryant, Bart
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 77 Player Data Successfully Acquired!: Bryant, Brad
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 78 Player Data Successfully Acquired!: Burgoon, Bronson
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 79 Player Data Successfully Acquired!: Burmester, Dean
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 80 Player Data Successfully Acquired!: Burns, Bob
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 81 Player Data Successfully Acquired!: Burns, George
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 82 Player Data Successfully Acquired!: Burns, Sam
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 83 Player Data Successfully Acquired!: Byman, Bob
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 84 Player Data Successfully Acquired!: Byrd, Jonathan
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 85 Player Data Successfully Acquired!: Byrne, James
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 86 Player Data Successfully Acquired!: Byrum, Curt
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 87 Player Data Successfully Acquired!: Byrum, Tom
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 88 Player Data Successfully Acquired!: Cabrera, Ãngel
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 89 Player Data Successfully Acquired!: Cabrera Bello, Rafa
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 90 Player Data Successfully Acquired!: Cairns, Brian
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 91 Player Data Successfully Acquired!: Calcavecchia, Mark
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 92 Player Data Successfully Acquired!: Caldwell, Rex
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 93 Player Data Successfully Acquired!: Campbell, Brian
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 94 Player Data Successfully Acquired!: Campbell, Chad
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 95 Player Data Successfully Acquired!: Cantlay, Patrick
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 96 Player Data Successfully Acquired!: Carballo, Miguel Angel
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 97 Player Data Successfully Acquired!: Carnevale, Mark
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 98 Player Data Successfully Acquired!: Carter, Jim
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 99 Player Data Successfully Acquired!: Casey, Paul
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 100 Player Data Successfully Acquired!: Casper, Billy
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 101 Player Data Successfully Acquired!: Castro, Roberto
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 102 Player Data Successfully Acquired!: Cauley, Bud
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 103 Player Data Successfully Acquired!: CaÃ±izares, Alejandro
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 104 Player Data Successfully Acquired!: Cejka, Alex
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 105 Player Data Successfully Acquired!: Cerrudo, Ron
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 106 Player Data Successfully Acquired!: Chalmers, Greg
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 107 Player Data Successfully Acquired!: Chamblee, Brandel
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 108 Player Data Successfully Acquired!: Champ, Cameron
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 109 Player Data Successfully Acquired!: Chappell, Kevin
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 110 Player Data Successfully Acquired!: Chawrasia, SSP
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 111 Player Data Successfully Acquired!: Chen, T.C.
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 112 Player Data Successfully Acquired!: Chin, John
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 113 Player Data Successfully Acquired!: Choi, Ho Sung
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 114 Player Data Successfully Acquired!: Choi, K.J.
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 115 Player Data Successfully Acquired!: Chopra, Daniel
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 116 Player Data Successfully Acquired!: Cink, Stewart
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 117 Player Data Successfully Acquired!: Clampett, Bobby
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 118 Player Data Successfully Acquired!: Clark, Tim
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 119 Player Data Successfully Acquired!: Clark, Wyndham
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 120 Player Data Successfully Acquired!: Clark II, Michael
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 121 Player Data Successfully Acquired!: Clarke, Darren
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 122 Player Data Successfully Acquired!: Claxton, Will
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 123 Player Data Successfully Acquired!: Clearwater, Keith
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 124 Player Data Successfully Acquired!: Clements, Lennie
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 125 Player Data Successfully Acquired!: Coceres, JosÃ©
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 126 Player Data Successfully Acquired!: Cochran, Russ
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 127 Player Data Successfully Acquired!: Coetzee, George
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 128 Player Data Successfully Acquired!: Colbert, Jim
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 129 Player Data Successfully Acquired!: Cole, Bobby
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 130 Player Data Successfully Acquired!: Collins, Chad
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 131 Player Data Successfully Acquired!: Colsaerts, Nicolas
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 132 Player Data Successfully Acquired!: Conner, Frank
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 133 Player Data Successfully Acquired!: Conners, Corey
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 134 Player Data Successfully Acquired!: Coody, Charles
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 135 Player Data Successfully Acquired!: Cook, Austin
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 136 Player Data Successfully Acquired!: Cook, John
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 137 Player Data Successfully Acquired!: Couch, Chris
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 138 Player Data Successfully Acquired!: Couples, Fred
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 139 Player Data Successfully Acquired!: Crampton, Bruce
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 140 Player Data Successfully Acquired!: Crane, Ben
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 141 Player Data Successfully Acquired!: Crenshaw, Ben
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 142 Player Data Successfully Acquired!: Curl, Rod
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 143 Player Data Successfully Acquired!: Curran, Jon
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 144 Player Data Successfully Acquired!: Curtis, Ben
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 145 Player Data Successfully Acquired!: Dahmen, Joel
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 146 Player Data Successfully Acquired!: Daly, John
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 147 Player Data Successfully Acquired!: Damron, Robert
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 148 Player Data Successfully Acquired!: Davis, Brian
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 149 Player Data Successfully Acquired!: Davis, Cameron
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 150 Player Data Successfully Acquired!: Dawson, Marco
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 151 Player Data Successfully Acquired!: Day, Glen
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 152 Player Data Successfully Acquired!: Day, Jason
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 153 Player Data Successfully Acquired!: de Jonge, Brendon
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 154 Player Data Successfully Acquired!: De Vicenzo, Roberto
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 155 Player Data Successfully Acquired!: DeChambeau, Bryson
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 156 Player Data Successfully Acquired!: DeLaet, Graham
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 157 Player Data Successfully Acquired!: Delsing, Jay
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 158 Player Data Successfully Acquired!: Dent, Jim
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 159 Player Data Successfully Acquired!: Devlin, Bruce
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 160 Player Data Successfully Acquired!: Dickson, Bob
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 161 Player Data Successfully Acquired!: Diehl, Terry
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 162 Player Data Successfully Acquired!: Dill, Terry
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 163 Player Data Successfully Acquired!: DiMarco, Chris
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 164 Player Data Successfully Acquired!: Dobyns, Matt
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 165 Player Data Successfully Acquired!: Dodds, Trevor
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 166 Player Data Successfully Acquired!: Dodt, Andrew
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 167 Player Data Successfully Acquired!: Donald, Luke
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 168 Player Data Successfully Acquired!: Donald, Mike
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 169 Player Data Successfully Acquired!: Donaldson, Jamie
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 170 Player Data Successfully Acquired!: Dougherty, Ed
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 171 Player Data Successfully Acquired!: Dougherty, Sean
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 172 Player Data Successfully Acquired!: Douglass, Dale
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 173 Player Data Successfully Acquired!: Dredge, Bradley
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 174 Player Data Successfully Acquired!: Dubuisson, Victor
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 175 Player Data Successfully Acquired!: Dufner, Jason
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 176 Player Data Successfully Acquired!: Duke, Ken
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 177 Player Data Successfully Acquired!: Duncan, Tyler
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 178 Player Data Successfully Acquired!: Dunne, Paul
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 179 Player Data Successfully Acquired!: Durant, Joe
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 180 Player Data Successfully Acquired!: Duval, David
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 181 Player Data Successfully Acquired!: Dyson, Simon
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 182 Player Data Successfully Acquired!: DÃ­az, Roberto
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 183 Player Data Successfully Acquired!: Eastwood, Bob
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 184 Player Data Successfully Acquired!: Edwards, Danny
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 185 Player Data Successfully Acquired!: Edwards, David
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 186 Player Data Successfully Acquired!: Edwards, Joel
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 187 Player Data Successfully Acquired!: Eichelberger, Dave
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 188 Player Data Successfully Acquired!: Elder, Lee
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 189 Player Data Successfully Acquired!: Elkington, Steve
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 190 Player Data Successfully Acquired!: Els, Ernie
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 191 Player Data Successfully Acquired!: English, Harris
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 192 Player Data Successfully Acquired!: Ernst, Derek
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 193 Player Data Successfully Acquired!: Estes, Bob
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 194 Player Data Successfully Acquired!: Etulain, JuliÃ¡n
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 195 Player Data Successfully Acquired!: Every, Matt
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 196 Player Data Successfully Acquired!: Fabel, Brad
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 197 Player Data Successfully Acquired!: Faldo, Nick
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 198 Player Data Successfully Acquired!: Fathauer, Derek
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 199 Player Data Successfully Acquired!: Faxon, Brad
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 200 Player Data Successfully Acquired!: Fehr, Rick
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 201 Player Data Successfully Acquired!: Fergus, Keith
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 202 Player Data Successfully Acquired!: Ferree, Jim
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 203 Player Data Successfully Acquired!: Fezler, Forrest
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 204 Player Data Successfully Acquired!: Finau, Tony
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 205 Player Data Successfully Acquired!: Finsterwald, Dow
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 206 Player Data Successfully Acquired!: Fiori, Ed
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 207 Player Data Successfully Acquired!: Fisher, Ross
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 208 Player Data Successfully Acquired!: Fitzpatrick, Matthew
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 209 Player Data Successfully Acquired!: Fitzsimons, Pat
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 210 Player Data Successfully Acquired!: Fleckman, Marty
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 211 Player Data Successfully Acquired!: Fleetwood, Tommy
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 212 Player Data Successfully Acquired!: Fleisher, Bruce
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 213 Player Data Successfully Acquired!: Flesch, Steve
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 214 Player Data Successfully Acquired!: Floyd, Raymond
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 215 Player Data Successfully Acquired!: Ford, Doug
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 216 Player Data Successfully Acquired!: Forsman, Dan
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 217 Player Data Successfully Acquired!: Fought, John
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 218 Player Data Successfully Acquired!: Fowler, Rickie
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 219 Player Data Successfully Acquired!: Fox, Ryan
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 220 Player Data Successfully Acquired!: Franco, Carlos
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 221 Player Data Successfully Acquired!: Frazar, Harrison
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 222 Player Data Successfully Acquired!: Freeman, Robin
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 223 Player Data Successfully Acquired!: Frittelli, Dylan
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 224 Player Data Successfully Acquired!: Frost, Charles
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 225 Player Data Successfully Acquired!: Frost, David
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 226 Player Data Successfully Acquired!: Fujimoto, Yoshinori
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 227 Player Data Successfully Acquired!: Fujita, Hiroyuki
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 228 Player Data Successfully Acquired!: Fulke, Pierre
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 229 Player Data Successfully Acquired!: Funk, Fred
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 230 Player Data Successfully Acquired!: Furyk, Jim
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 231 Player Data Successfully Acquired!: Gaffney, Brian
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 232 Player Data Successfully Acquired!: Gainey, Tommy
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 233 Player Data Successfully Acquired!: Gallacher, Stephen
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 234 Player Data Successfully Acquired!: Gallagher, Jr., Jim
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 235 Player Data Successfully Acquired!: Gamez, Robert
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 236 Player Data Successfully Acquired!: Garber, Joey
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 237 Player Data Successfully Acquired!: Garcia, Sergio
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 238 Player Data Successfully Acquired!: Gardner, Buddy
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 239 Player Data Successfully Acquired!: Garnett, Brice
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 240 Player Data Successfully Acquired!: Garrigus, Robert
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 241 Player Data Successfully Acquired!: Gay, Brian
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 242 Player Data Successfully Acquired!: Geiberger, Al
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 243 Player Data Successfully Acquired!: Geiberger, Brent
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 244 Player Data Successfully Acquired!: Gibson, Kelly
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 245 Player Data Successfully Acquired!: Gilbert, Gibby
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 246 Player Data Successfully Acquired!: Gilder, Bob
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 247 Player Data Successfully Acquired!: Gillespie, Nick
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 248 Player Data Successfully Acquired!: Glasson, Bill
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 249 Player Data Successfully Acquired!: Glover, Lucas
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 250 Player Data Successfully Acquired!: Glover, Randy
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 251 Player Data Successfully Acquired!: Goalby, Bob
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 252 Player Data Successfully Acquired!: Gogel, Matt
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 253 Player Data Successfully Acquired!: Gonzalez, Ernie
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 254 Player Data Successfully Acquired!: Gooch, Talor
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 255 Player Data Successfully Acquired!: Goosen, Retief
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 256 Player Data Successfully Acquired!: Gore, Jason
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 257 Player Data Successfully Acquired!: Gossett, David
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 258 Player Data Successfully Acquired!: Goydos, Paul
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 259 Player Data Successfully Acquired!: Grace, Branden
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 260 Player Data Successfully Acquired!: Graham, David
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 261 Player Data Successfully Acquired!: Green, Hubert
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 262 Player Data Successfully Acquired!: Green, Ken
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 263 Player Data Successfully Acquired!: Green, Nathan
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 264 Player Data Successfully Acquired!: Gribble, Cody
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 265 Player Data Successfully Acquired!: Grillo, Emiliano
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 266 Player Data Successfully Acquired!: Grob, Mike
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 267 Player Data Successfully Acquired!: Groh, Gary
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 268 Player Data Successfully Acquired!: Gump, Scott
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 269 Player Data Successfully Acquired!: GÃ³mez, FabiÃ¡n
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 270 Player Data Successfully Acquired!: Haas, Bill
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 271 Player Data Successfully Acquired!: Haas, Jay
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 272 Player Data Successfully Acquired!: Hadley, Chesson
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 273 Player Data Successfully Acquired!: Hadwin, Adam
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 274 !!!!!!!!!!!Data Retrieval Unsuccessful: Hagen, Walter
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 275 Player Data Successfully Acquired!: Hagy, Brandon
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 276 Player Data Successfully Acquired!: Hahn, James
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 277 Player Data Successfully Acquired!: Hahn, John
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 278 Player Data Successfully Acquired!: Hallberg, Gary
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 279 Player Data Successfully Acquired!: Haller, Ryan
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 280 Player Data Successfully Acquired!: Hamilton, Todd
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 281 Player Data Successfully Acquired!: Hammer, Laurie
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 282 Player Data Successfully Acquired!: Hammond, Donnie
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 283 Player Data Successfully Acquired!: Han, Seungsu
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 284 Player Data Successfully Acquired!: Hancock, Phillip
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 285 Player Data Successfully Acquired!: Hansen, Anders
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 286 Player Data Successfully Acquired!: Hanson, Peter
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 287 Player Data Successfully Acquired!: Harding, Justin
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 288 Player Data Successfully Acquired!: Harkins, Brandon
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 289 Player Data Successfully Acquired!: Harman, Brian
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 290 Player Data Successfully Acquired!: Harrington, Padraig
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 291 Player Data Successfully Acquired!: Harris, Labron
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 292 Player Data Successfully Acquired!: Hart, Dudley
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 293 Player Data Successfully Acquired!: Hatalsky, Morris
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 294 Player Data Successfully Acquired!: Hatton, Tyrrell
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 295 Player Data Successfully Acquired!: Hayes, J.P.
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 296 Player Data Successfully Acquired!: Heard, Jerry
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 297 Player Data Successfully Acquired!: Hearn, David
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 298 Player Data Successfully Acquired!: Heinen, Mike
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 299 Player Data Successfully Acquired!: Helminen, Ryan
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 300 Player Data Successfully Acquired!: Henke, Nolan
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 301 Player Data Successfully Acquired!: Henley, Russell
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 302 Player Data Successfully Acquired!: Henninger, Brian
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 303 Player Data Successfully Acquired!: Henry, Bunky
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 304 Player Data Successfully Acquired!: Henry, J.J.
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 305 Player Data Successfully Acquired!: Hensby, Mark
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 306 Player Data Successfully Acquired!: Herman, Jim
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 307 Player Data Successfully Acquired!: Herron, Tim
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 308 Player Data Successfully Acquired!: Hickok, Kramer
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 309 Player Data Successfully Acquired!: Hinkle, Lon
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 310 Player Data Successfully Acquired!: Hinson, Larry
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 311 Player Data Successfully Acquired!: Hiskey, Babe
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 312 Player Data Successfully Acquired!: Hjertstedt, Gabriel
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 313 Player Data Successfully Acquired!: Hoch, Scott
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 314 Player Data Successfully Acquired!: Hoffman, Charley
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 315 Player Data Successfully Acquired!: Hoffmann, Morgan
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 316 !!!!!!!!!!!Data Retrieval Unsuccessful: Hogan, Ben
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 317 Player Data Successfully Acquired!: Hoge, Tom
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 318 Player Data Successfully Acquired!: Holmes, J.B.
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 319 Player Data Successfully Acquired!: Homa, Max
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 320 Player Data Successfully Acquired!: Horschel, Billy
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 321 Player Data Successfully Acquired!: Hossler, Beau
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 322 Player Data Successfully Acquired!: Howell, David
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 323 Player Data Successfully Acquired!: Howell III, Charles
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 324 Player Data Successfully Acquired!: Hughes, Mackenzie
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 325 Player Data Successfully Acquired!: Huh, John
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 326 Player Data Successfully Acquired!: Hulbert, Mike
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 327 Player Data Successfully Acquired!: Hurley III, Billy
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 328 Player Data Successfully Acquired!: Huston, John
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 329 Player Data Successfully Acquired!: Ikeda, Yuta
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 330 Player Data Successfully Acquired!: Ilonen, Mikko
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 331 Player Data Successfully Acquired!: Im, Sungjae
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 332 Player Data Successfully Acquired!: Imada, Ryuji
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 333 Player Data Successfully Acquired!: Immelman, Trevor
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 334 Player Data Successfully Acquired!: Inman, Joe
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 335 Player Data Successfully Acquired!: Inman, John
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 336 Player Data Successfully Acquired!: Irwin, Hale
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 337 Player Data Successfully Acquired!: Iverson, Don
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 338 Player Data Successfully Acquired!: Jacklin, Tony
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 339 Player Data Successfully Acquired!: Jacobs, Tommy
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 340 Player Data Successfully Acquired!: Jacobsen, Peter
# scraped URL
# try visit url
# done visit url
# try click performance
# except try click performance
# done click performance except
# 341 Player Data Successfully Acquired!: Jacobson, Freddie
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 342 Player Data Successfully Acquired!: Jaeckel, Barry
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 343 Player Data Successfully Acquired!: Jaeger, Stephan
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 344 Player Data Successfully Acquired!: Jaidee, Thongchai
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 345 Player Data Successfully Acquired!: Jamieson, Jim
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 346 Player Data Successfully Acquired!: Jamieson, Scott
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 347 Player Data Successfully Acquired!: January, Don
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 348 Player Data Successfully Acquired!: Janzen, Lee
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 349 Player Data Successfully Acquired!: Jenkins, Tom
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 350 Player Data Successfully Acquired!: Jeong, Jin
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 351 Player Data Successfully Acquired!: Jin, Cheng
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 352 Player Data Successfully Acquired!: Jobe, Brandt
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 353 Player Data Successfully Acquired!: Johnson, Dustin
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 354 Player Data Successfully Acquired!: Johnson, Richard
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 355 Player Data Successfully Acquired!: Johnson, Zach
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 356 Player Data Successfully Acquired!: Johnston, Al
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 357 Player Data Successfully Acquired!: Johnston, Bill
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 358 Player Data Successfully Acquired!: Jones, Brendan
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 359 Player Data Successfully Acquired!: Jones, Brett
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 360 Player Data Successfully Acquired!: Jones, Grier
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 361 Player Data Successfully Acquired!: Jones, Kent
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 362 Player Data Successfully Acquired!: Jones, Kyle
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 363 Player Data Successfully Acquired!: Jones, Matt
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 364 Player Data Successfully Acquired!: Jones, Steve
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 365 Player Data Successfully Acquired!: Kang, Jiman
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 366 Player Data Successfully Acquired!: Kang, Sung
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 367 Player Data Successfully Acquired!: Karl, Richie
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 368 Player Data Successfully Acquired!: Karlberg, Rikard
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 369 Player Data Successfully Acquired!: Karlsson, Robert
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 370 Player Data Successfully Acquired!: Kaufman, Smylie
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 371 Player Data Successfully Acquired!: Kaye, Jonathan
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 372 Player Data Successfully Acquired!: Kaymer, Martin
# scraped URL
# try visit url
# done visit url
# try click performance
# done click performance
# 373 Player Data Successfully Acquired!: Kelly, Andrew
# 374 !!!!!!!!!!!Data Retrieval Unsuccessful: Kelly, Andrew
# scraped URL
# try visit url
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-308042e98341> in <module>
#      77     print("try visit url")
#      78     browser.visit(scrape_url)
# ---> 79     time.sleep(8)
#      80     print("done visit url")
#      81
#
# KeyboardInterrupt:

# %%
#get all player names of each list in DATA
DATA_player_names = [d['player_intro']['Player Name'] for d in DATA]

# %%
#add titleist player info to DATA set
for player in titleist_players:
    #get name to match to master data set
    name = player['Player Name']
    print(name)
    #find which item in master data set this name matches
    index = [i for i, s in enumerate(DATA_player_names) if name in s]
    print(index)
    #create new list item/dictionary for only titleist players in master data set
    #DATA[index[0]]['Titleist'] = player

# %%
#APPEND TEST

# %%
DATA_copy = DATA[:]
titleist_copy = titleist_players[:]

# %%
DATA_copy = DATA_copy[737]
DATA_copy

# %%
player_test = titleist_copy[0]
player_test

# %%
DATA_copy['player_intro']['Player Name']

# %%
player_test['Player Name']

# %%
DATA_copy['player_intro']['Player Name'] == player_test['Player Name']

# %%
player_test

# %%
DATA_copy['player_intro'].update(player_test)

# %%
DATA_copy

# %% [markdown]
# ## MongoDB Data Storage

# %%
#DECLARE WHAT NUMBER SCRAPE THIS IS
x = 4

# %%
import pymongo
from bson import ObjectId
import datetime

# %%
# Create connection variable
conn = 'mongodb://localhost:27017'

# %%
# Pass connection to the pymongo instance.
client = pymongo.MongoClient(conn)

# %%
# Connect to a database. Will create one if not already available.
db = client.pga_data["collection"+f"{x}"]

# %%
now = datetime.datetime.now()

# %%
# create mongo collection
#collection = db.data

# %%
for d in DATA:
    dict_ = {"_id" : d['player_intro']['Player Name']}
    for x in d:
        dict_[f"{x}"]  = d[f"{x}"]
    try:
        db.insert_one(dict_)
    except:
        nothing = 0

# %%
#x.inserted_id

# %%
#bla = db.collection.find_one({'_id':ObjectId('5cd799a186fd7a260400d731')})
#bla

# %% [markdown]
# ## Get Data from MongoDB

# %%
mongo_data = db.find()

# %%
mongo_data

# %%
data['player_intro']

# %%
pga_data_all = db.find()
player_intro = []
for player in pga_data_all:
    player_intro.append(player)

# %%
test = []
mongo_data = db.find()
for data in mongo_data:
    test.append(data)
test

# %% [markdown]
# Works

# %%
test_data = db.find()

# %%
for bla in range(0,10):
    print(test_data[bla]['player_intro'])

# %%
test_data[1]['all_stat_var']
